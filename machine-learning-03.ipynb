# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Exploratory Data Analysis (EDA)

import joblib

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics._regression import mean_absolute_error, mean_squared_error, root_mean_squared_error
from colorama import Fore

# %% [markdown]
# ## Task info
#
# Your task
#
# Implement a machine learning system that predicts being diagnosed with heart disease
#
# 1) Apply EDA to extract useful insights
# 2) Build your preprocessing pipeline consisting of scaling, label-encoding, one-hot encoding
# 3) Try the 3 models we covered logistic regression, svm & knn
#
# Evaluate your model accuracy, precesion, recall, ......
#
# Kindly deploy on a streamlit app

# %%
os.listdir('data/raw/')
# Out:
# ['Heart-Disease-Patients-Records.csv']

# %%
df = pd.read_csv('data/preprocessed-data/preprocessed-data.csv')

# %% [markdown]
# # Data info
# - -EDA-1 =
# - A /data/raw/Exam_Score_Prediction.csv
# - B data/feature eng data/feature_eng_data.csv
#
# - -Pre-processed-2
# - A data/feature eng data/feature_eng_data.csv
# - B data/preprocessed data/pre-processed_data.csv
#
# - -Machine-learning-3 =
# - A /data/preprocessed data/pre-processed_data.csv
# - B /artifacts/svm_pipeline.pkl

# %%
df.sample(2)
# Out:
#      age  chest_pain_type  resisting_blood_pressure  cholesterol_level  \
# 207   41                2                       112                250
# 212   50                3                       150                243
#
#      max_heart_rate_achieved  st_depression  num_major_vessels  thalassemia  \
# 207                      179            0.0                  0            1
# 212                      128            2.6                  0            2
#
#         diagnosis  sex_female  ...  fasting_blood_sugar_higher than 120mg/ml  \
# 207  Un-Diagnosed           0  ...                                         0
# 212     Diagnosed           0  ...                                         0
#
#      fasting_blood_sugar_lower than 120mg/ml  rest_ecg_ST-T wave abnormality  \
# 207                                        1                               1
# 212                                        1                               0
#
# ...

# %%
df.shape
# Out:
# (1024, 21)

# %%
df.columns
# Out:
# Index(['age', 'chest_pain_type', 'resisting_blood_pressure',
#        'cholesterol_level', 'max_heart_rate_achieved', 'st_depression',
#        'num_major_vessels', 'thalassemia', 'diagnosis', 'sex_female',
#        'sex_male', 'fasting_blood_sugar_higher than 120mg/ml',
#        'fasting_blood_sugar_lower than 120mg/ml',
#        'rest_ecg_ST-T wave abnormality',
#        'rest_ecg_left ventricular hypertrophy', 'rest_ecg_normal',
#        'st_slope_downsloping', 'st_slope_flat', 'st_slope_upsloping',
#        'exercise_induced_angina_no', 'exercise_induced_angina_yes'],
#       dtype='object')

# %% [markdown]
# # Split freatures into X and y

# %% [markdown]
# ## Die sicherere Lösung für deinen Code:
# Damit dein Modell wirklich medizinisch lernt, solltest du beide Diagnose-Spalten aus X entfernen:

# %%
# Wir löschen BEIDE Diagnose-Spalten aus X
X = df.drop(columns=['diagnosis_Diagnosed', 'diagnosis_Un-Diagnosed'])

# Und setzen eine davon als unser Ziel y
y = df['diagnosis_Diagnosed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Wir löschen BEIDE Diagnose-Spalten aus X
# ----> 2 X = df.drop(columns=['diagnosis_Diagnosed', 'diagnosis_Un-Diagnosed'])
#       4 # Und setzen eine davon als unser Ziel y
#       5 y = df['diagnosis_Diagnosed']
#
# File c:\Users\X2-win\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
# ...

# %%
X.shape
# Out:
# (1024, 20)

# %% [markdown]
# ### Split inti training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.20, random_state= 42)

# %% [markdown]
# Model Selection
# - Ensemble models =  kombiniert mehrere Einzelmodelle, um genauere Vorhersagen zu treffen als ein einzelnes Modell allein

# %%
knn_model = KNeighborsRegressor( n_neighbors= 1)

# %%
X_train.shape
# Out:
# (819, 20)

# %%
X_test.shape
# Out:
# (205, 20)

# %%
y_test
# Out:
# 525    1
# 357    1
# 444    0
# 31     0
# 618    1
#       ..
# 542    1
# 903    0
# 528    0
# 294    1
# 745    1
# Name: diagnosis_Diagnosed, Length: 205, dtype: int64

# %%
y_train
# Out:
# 137    0
# 377    1
# 388    0
# 824    0
# 767    0
#       ..
# 106    1
# 270    0
# 860    1
# 435    1
# 102    0
# Name: diagnosis_Diagnosed, Length: 819, dtype: int64

# %%
knn_model.fit( X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
y_pred_train = knn_model.predict ( X_train)
y_pred_train [:5]
# Out:
# array([0., 1., 0., 0., 0.])

# %%
y_test[100:106]
# Out:
# 894     1
# 107     1
# 881     1
# 1010    0
# 299     0
# 548     0
# Name: diagnosis_Diagnosed, dtype: int64

# %%
y_pred_test = knn_model.predict( X_test )

# %%
y_pred_test [100:106]
# Out:
# array([1., 1., 1., 0., 0., 0.])

# %%
pd.DataFrame({
    'Actural': y_test[100:110],
    'Predicted': y_pred_test[100:110],
    'Residuals': y_test[100:110] - y_pred_test [100:110]
})
# Out:
#       Actural  Predicted  Residuals
# 894         1        1.0        0.0
# 107         1        1.0        0.0
# 881         1        1.0        0.0
# 1010        0        0.0        0.0
# 299         0        0.0        0.0
# 548         0        0.0        0.0
# 1002        0        0.0        0.0
# 929         1        1.0        0.0
# 342         0        0.0        0.0
# 714         0        0.0        0.0

# %% [markdown]
# ## Metrics
# - MAE = mean absolute error
# - MSE = mean squared error
# - RMSE = root mean squared error

# %%
MAE_train = mean_absolute_error ( y_train, y_pred_train)
MAE_test = mean_absolute_error ( y_test, y_pred_test)

MSE_train = mean_squared_error ( y_train, y_pred_train )
MSE_test = mean_squared_error ( y_test, y_pred_test)

RMSE_train = root_mean_squared_error ( y_train, y_pred_train)
RMSE_test = root_mean_squared_error ( y_test, y_pred_test)

print( f'Mean absolute error of training:  {MAE_train}')
print( f'Mean absolute error of testing {MAE_test}')

print( )
print( f'Mean squared error of training {MSE_train}')
print( f'Mean squared error of testing {MSE_test}')

print( )
print( f'Root mean squared error of training {RMSE_train}')
print( f'Root mean squred error of training {RMSE_test}')
# Out:
# Mean absolute error of training:  0.0
# Mean absolute error of testing 0.01951219512195122
#
# Mean squared error of training 0.0
# Mean squared error of testing 0.01951219512195122
#
# Root mean squared error of training 0.0
# Root mean squred error of training 0.13968605915391563

# %%
cross_val_score ( knn_model, X_train, y_train, cv= 4, scoring='neg_root_mean_squared_error').mean()
# Out:
# np.float64(-0.24829072839021865)

# %% [markdown]
# Testing GridSearchCV on KNN Model

# %%
knn_model = KNeighborsRegressor( )

# %%
gs_knn = GridSearchCV(
    estimator= knn_model, 
    param_grid= { 'n_neighbors': [ 2, 3, 4, 5, 6, 7]}
)

# %%
gs_knn.fit( X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [2, 3, 4, 5, 6, 7]})

# %%
gs_knn.best_params_
# Out:
# {'n_neighbors': 2}

# %%
knn_comparion_df = pd.DataFrame({
    'Actual ( True )': y_test,
    'Predicted ( KNN )': y_pred_test,
    'Residuals':  np.abs( y_test - y_pred_test)
}) 

knn_comparion_df
# Out:
#      Actual ( True )  Predicted ( KNN )  Residuals
# 525                1                1.0        0.0
# 357                1                1.0        0.0
# 444                0                0.0        0.0
# 31                 0                0.0        0.0
# 618                1                1.0        0.0
# ..               ...                ...        ...
# 542                1                1.0        0.0
# 903                0                0.0        0.0
# 528                0                0.0        0.0
# 294                1                1.0        0.0
# 745                1                1.0        0.0
#
# [205 rows x 3 columns]

# %%
knn_comparion_df.head(10)
# Out:
#      Actual ( True )  Predicted ( KNN )  Residuals
# 525                1                1.0        0.0
# 357                1                1.0        0.0
# 444                0                0.0        0.0
# 31                 0                0.0        0.0
# 618                1                1.0        0.0
# 587                1                1.0        0.0
# 447                0                0.0        0.0
# 734                0                0.0        0.0
# 76                 0                0.0        0.0
# 715                1                1.0        0.0

# %% [markdown]
# # [2] Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg_model = LinearRegression()

# %%
lin_reg_model.fit( X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train_lr = lin_reg_model.predict( X_train)
y_pred_test_lr = lin_reg_model.predict( X_test )

# %%
y_pred_train_lr
# Out:
# array([ 3.12856080e-01,  6.78350436e-01,  1.83744157e-01, -6.52455561e-04,
#         1.97312469e-01,  1.27285814e-01,  2.66931103e-01, -6.06402707e-02,
#         1.91533615e-01,  7.96164995e-01,  9.80806189e-01,  5.16785214e-01,
#         8.04122311e-01,  1.17785010e+00,  2.12743158e-01,  8.91669300e-01,
#         4.02553906e-03,  9.01565830e-01,  1.12485435e+00,  4.47328648e-01,
#         3.07910931e-02,  1.02691455e+00,  3.92231143e-01,  3.30866949e-01,
#         3.18573261e-01,  4.14443176e-01,  3.42153347e-01,  7.37489116e-01,
#         6.38574323e-01,  9.49473444e-01,  1.10015519e+00,  4.10459234e-01,
#         6.29932736e-01,  9.01565830e-01,  6.15273065e-01,  7.43294294e-01,
#         8.35261926e-01,  1.16899053e-01,  4.13152395e-01,  1.01474858e-02,
#         5.66163150e-01,  3.92582709e-01,  8.25120337e-01,  6.29932736e-01,
#         8.44254179e-01,  6.78350436e-01,  1.59499246e-01,  1.44938865e-01,
# ...

# %%
y_train
# Out:
# 137    0
# 377    1
# 388    0
# 824    0
# 767    0
#       ..
# 106    1
# 270    0
# 860    1
# 435    1
# 102    0
# Name: diagnosis_Diagnosed, Length: 819, dtype: int64

# %%
lin_reg_model.intercept_
# Out:
# np.float64(-0.028475342716918317)

# %%
X_train.shape
# Out:
# (819, 20)

# %%
lin_reg_model.coef_
# Out:
# array([ 0.00039508,  0.09969262,  0.00136367,  0.00059744, -0.00230218,
#         0.05992307,  0.09548682,  0.14151112, -0.11115436,  0.11115436,
#         0.0158203 , -0.0158203 , -0.06662007,  0.0845431 , -0.01792303,
#        -0.07389304,  0.06719875,  0.00669429, -0.05784992,  0.05784992])

# %%
print( 'Linear Regression Wvaluation :')
print(35* '--')
print( )
MAE_train = mean_absolute_error ( y_train, y_pred_train_lr)
MAE_test = mean_absolute_error ( y_test, y_pred_test_lr)

MSE_train = mean_squared_error ( y_train, y_pred_train_lr )
MSE_test = mean_squared_error ( y_test, y_pred_test_lr)

RMSE_train = root_mean_squared_error ( y_train, y_pred_train_lr)
RMSE_test = root_mean_squared_error ( y_test, y_pred_test_lr)

print( f'Mean absolute error of training:  {MAE_train}')
print( f'Mean absolute error of testing {MAE_test}')

print( )
print( f'Mean squared error of training {MSE_train}')
print( f'Mean squared error of testing {MSE_test}')

print( )
print( f'Root mean squared error of training {RMSE_train}')
print( f'Root mean squred error of training {RMSE_test}')
# Out:
# Linear Regression Wvaluation :
# ----------------------------------------------------------------------
#
# Mean absolute error of training:  0.27847996124112007
# Mean absolute error of testing 0.2805702197276905
#
# Mean squared error of training 0.12166319741327589
# Mean squared error of testing 0.12464246027415576
#
# Root mean squared error of training 0.34880251921864885
# Root mean squred error of training 0.35304739097486015

# %% [markdown]
# # Define a functin to evaluate any regressor

# %%
def evaluate_regressor( model, model_name: str, X_train, X_test, y_trin, y_test):

    print( 'Training name:' + 41 * '-' + '\n')

    print( model_name + ':')
    print( '-' * 55)

    model.fit( X_train, y_train )
    y_pred_train = model.predict( X_train )
    y_pred_test = model.predict ( X_test )

    print( )

    MAE_train = mean_absolute_error( y_train, y_pred_train )
    MSE_train = mean_squared_error( y_train, y_pred_train )
    RMSE_train = root_mean_squared_error( y_train, y_pred_train )
    
    MAE_test = mean_absolute_error( y_test, y_pred_test )
    MSE_test = mean_squared_error( y_test, y_pred_test )
    RMSE_test = root_mean_squared_error( y_test, y_pred_test )

    print( f'Mean Absolute Error of training : { MAE_train }' )
    print( Fore.CYAN + f'Mean Squared Error of training : { MSE_train }' )
    print( Fore.WHITE + f'Root Mean Squared Error of Training : { RMSE_train }' )
    print(  )

    print( Fore.WHITE + f'Mean Absolute Error of Testing : { MAE_test }' )
    print( Fore.RED  + f'Mean Squared Error of Testing : { MSE_test }' )
    print( Fore.WHITE + f'Root Mean Squared Error of Testing : { RMSE_test }' )

# %% [markdown]
# # [1] KNN

# %%
knn_model = KNeighborsRegressor( n_neighbors= 7 )

# %%
evaluate_regressor( knn_model, 'K Neighbors Regressor', X_train, X_test, y_train, y_test)
# Out:
# Training name:-----------------------------------------
#
# K Neighbors Regressor:
# -------------------------------------------------------
#
# Mean Absolute Error of training : 0.25065410779696495
# Mean Squared Error of training : 0.12167650943161147
# Root Mean Squared Error of Training : 0.3488216011539587
#
# Mean Absolute Error of Testing : 0.28432055749128915
# Mean Squared Error of Testing : 0.15788949726231957
# Root Mean Squared Error of Testing : 0.39735311407150137

# %% [markdown]
# # [2] Linear Regression

# %%
lin_reg_model = LinearRegression()

# %%
evaluate_regressor( lin_reg_model, 'Linear Regression without regularizaion', X_train, X_test, y_train, y_test)
# Out:
# Training name:-----------------------------------------
#
# Linear Regression without regularizaion:
# -------------------------------------------------------
#
# Mean Absolute Error of training : 0.27847996124112007
# Mean Squared Error of training : 0.12166319741327589
# Root Mean Squared Error of Training : 0.34880251921864885
#
# Mean Absolute Error of Testing : 0.2805702197276905
# Mean Squared Error of Testing : 0.12464246027415576
# Root Mean Squared Error of Testing : 0.35304739097486015

# %% [markdown]
# # [3] Linear Regression with regularization L1 (Lasso )

# %%
lin_reg_L1 = Lasso ( alpha = 0.2 )

# %%
evaluate_regressor (  lin_reg_L1, 'Linear Regression with Regularizaion ( L1 )', X_train, X_test, y_train, y_test)
# Out:
# Training name:-----------------------------------------
#
# Linear Regression with Regularizaion ( L1 ):
# -------------------------------------------------------
#
# Mean Absolute Error of training : 0.4107384481377937
# Mean Squared Error of training : 0.20211096907293347
# Root Mean Squared Error of Training : 0.44956753560831486
#
# Mean Absolute Error of Testing : 0.3968138802982935
# Mean Squared Error of Testing : 0.19346643093458094
# Root Mean Squared Error of Testing : 0.43984819078243453

# %% [markdown]
# ## [4] Linear Regression with regularization L2 ( Ridge )
# - Dieser Befehl erstellt ein Ridge-Regressionsmodell, das auch als L2-Regularisierung bekannt ist.
# - Genau wie Lasso hilft Ridge dabei, Overfitting (Überanpassung) zu verhindern, nutzt dafür aber eine andere mathematische Methode.
# #### Das passiert im Hintergrund:
# - Bestrafung grosser Gewichte: Ridge fügt der Fehlerberechnung eine Strafe hinzu, die auf den Quadraten der Koeffizienten basiert.
# - Schrumpfung (Shrinkage): Das Modell versucht, die Koeffizienten so klein wie möglich zu halten, damit kein einzelnes Merkmal die Vorhersage zu extrem dominiert.
# - Der grosse Unterschied zu Lasso: Ridge setzt Koeffizienten fast nie exakt auf Null. Es behält alle Merkmale im Modell, schwächt die unwichtigen aber extrem stark ab.

# %%
ridge = Ridge( )

# %%
evaluate_regressor ( ridge, 'Linear Regression with Regularizaion ( L2 )', X_train, X_test, y_train, y_test)
# Out:
# Training name:-----------------------------------------
#
# Linear Regression with Regularizaion ( L2 ):
# -------------------------------------------------------
#
# Mean Absolute Error of training : 0.27861758714402446
# Mean Squared Error of training : 0.12166419909911758
# Root Mean Squared Error of Training : 0.34880395510819195
#
# Mean Absolute Error of Testing : 0.2806924728939031
# Mean Squared Error of Testing : 0.12461249813901538
# Root Mean Squared Error of Testing : 0.3530049548363527

# %% [markdown]
# # [5] Support verctor machine

# %%
from sklearn.svm import SVR

# %%
svm_regressor = SVR( )

# %%
evaluate_regressor( svm_regressor, 'SVM', X_train, X_test, y_train, y_test)
# Out:
# Training name:-----------------------------------------
#
# SVM:
# -------------------------------------------------------
#
# Mean Absolute Error of training : 0.37834551500449937
# Mean Squared Error of training : 0.20073535364228817
# Root Mean Squared Error of Training : 0.448034991537813
#
# Mean Absolute Error of Testing : 0.36174920278500966
# Mean Squared Error of Testing : 0.19637043562116963
# Root Mean Squared Error of Testing : 0.44313703932437154

# %% [markdown]
# # [6] Support Vector machine with Scaling ( SVM )

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
svm_pipeline = make_pipeline(
    StandardScaler(),
    svm_regressor
)

# %%
svm_pipeline
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svr', SVR())])

# %%
evaluate_regressor( svm_pipeline, 'SVM with Scaling', X_train, X_test, y_train, y_test)
# Out:
# Training name:-----------------------------------------
#
# SVM with Scaling:
# -------------------------------------------------------
#
# Mean Absolute Error of training : 0.12172246634726455
# Mean Squared Error of training : 0.03289763718340559
# Root Mean Squared Error of Training : 0.18137705804044124
#
# Mean Absolute Error of Testing : 0.13233537984303526
# Mean Squared Error of Testing : 0.03945135753826874
# Root Mean Squared Error of Testing : 0.19862365805278268

# %%
joblib.dump( svm_pipeline, '../ml_Session_23_Task_Heart-Disease-Patients-Records/artifacts/svm_pipeline.pkl')
# Out:
# ['../ml_Session_23_Task_Heart-Disease-Patients-Records/artifacts/svm_pipeline.pkl']
